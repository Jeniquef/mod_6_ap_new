# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
pip install geoviews
# Out:
# Requirement already satisfied: geoviews in c:\users\19082\anaconda3\lib\site-packages (1.14.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: bokeh>=3.6.0 in c:\users\19082\anaconda3\lib\site-packages (from geoviews) (3.6.2)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\19082\anaconda3\lib\site-packages (from geoviews) (0.24.1)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\19082\anaconda3\lib\site-packages (from geoviews) (1.19.0)
# Requirement already satisfied: numpy in c:\users\19082\anaconda3\lib\site-packages (from geoviews) (1.26.4)
# Requirement already satisfied: packaging in c:\users\19082\anaconda3\lib\site-packages (from geoviews) (23.2)
# Requirement already satisfied: panel>=1.0.0 in c:\users\19082\anaconda3\lib\site-packages (from geoviews) (1.6.0)
# Requirement already satisfied: param<3.0,>=1.9.3 in c:\users\19082\anaconda3\lib\site-packages (from geoviews) (2.1.0)
# Requirement already satisfied: pyproj in c:\users\19082\anaconda3\lib\site-packages (from geoviews) (3.7.0)
# Requirement already satisfied: shapely in c:\users\19082\anaconda3\lib\site-packages (from geoviews) (2.0.7)
# Requirement already satisfied: xyzservices in c:\users\19082\anaconda3\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\19082\anaconda3\lib\site-packages (from bokeh>=3.6.0->geoviews) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\19082\anaconda3\lib\site-packages (from bokeh>=3.6.0->geoviews) (1.2.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\19082\anaconda3\lib\site-packages (from bokeh>=3.6.0->geoviews) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\19082\anaconda3\lib\site-packages (from bokeh>=3.6.0->geoviews) (10.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\19082\anaconda3\lib\site-packages (from bokeh>=3.6.0->geoviews) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\19082\anaconda3\lib\site-packages (from bokeh>=3.6.0->geoviews) (6.4.1)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\19082\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.8.4)
# Requirement already satisfied: pyshp>=2.3 in c:\users\19082\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: colorcet in c:\users\19082\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.1.0)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\19082\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.2)
# Requirement already satisfied: bleach in c:\users\19082\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: linkify-it-py in c:\users\19082\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: markdown in c:\users\19082\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\19082\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\19082\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in c:\users\19082\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.32.2)
# Requirement already satisfied: tqdm in c:\users\19082\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.66.4)
# Requirement already satisfied: typing-extensions in c:\users\19082\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.11.0)
# Requirement already satisfied: certifi in c:\users\19082\anaconda3\lib\site-packages (from pyproj->geoviews) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\19082\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=3.6.0->geoviews) (2.1.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\19082\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\19082\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\19082\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\19082\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\19082\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\19082\anaconda3\lib\site-packages (from pandas>=1.2->bokeh>=3.6.0->geoviews) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\19082\anaconda3\lib\site-packages (from pandas>=1.2->bokeh>=3.6.0->geoviews) (2023.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\19082\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\19082\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\19082\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\19082\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\19082\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\19082\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\19082\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.2.2)
# Requirement already satisfied: colorama in c:\users\19082\anaconda3\lib\site-packages (from tqdm->panel>=1.0.0->geoviews) (0.4.6)

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from geoviews import opts
import geoviews.feature as gf



# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 0        0             kailua-kona  19.6406 -155.9956     27.38        76
# 1        1               vorgashor  67.5833   63.9500    -26.42        99
# 2        2           haiku-pauwela  20.9219 -156.3051     27.16        69
# 3        3  hawaiian paradise park  19.5933 -154.9731     24.94        93
# 4        4               grytviken -54.2811  -36.5092     10.25        62
#
#    Cloudiness  Wind Speed Country        Date
# 0          75        8.23      US  1738371552
# 1          86        1.63      RU  1738371345
# 2         100       10.28      US  1738371554
# 3          75        3.09      US  1738371555
# 4         100        2.29      GS  1738371556

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display


# Configure the map plot
map_plot = city_data_df.hvplot.points(
    'Lng', 'Lat', 
    geo=True, 
    size='Humidity',  # Set point size based on the 'Humidity' column
    alpha=0.6, 
    color='Humidity',  
    tiles='OSM', 
    frame_width=800, 
    frame_height=600, 
    hover_cols=['City', 'Country', 'Humidity'] 
)
# Display the map
map_plot.opts(opts.Points(tools=['hover'], colorbar=True, size=10))
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City,Country)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_cities_df = city_data_df[
    (city_data_df["Max Temp"] >= 20) & 
    (city_data_df["Max Temp"] <= 60) & 
    (city_data_df["Humidity"] < 75) & 
    (city_data_df["Cloudiness"] < 20)
]

# Drop any rows with null values
ideal_cities_df = ideal_cities_df.dropna()

# Display sample data
ideal_cities_df.head()
# Out:
#     City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 7         7     east london -33.0153   27.9116     20.75        68
# 13       13  sarandi del yi -33.3500  -55.6333     22.31        57
# 15       15     les avirons -21.2418   55.3394     24.05        69
# 31       31         mildura -34.2000  142.1500     32.82        40
# 76       76   alice springs -23.7000  133.8833     34.75         8
#
#     Cloudiness  Wind Speed Country        Date
# 7            0        3.40      ZA  1738371560
# 13           0        6.95      UY  1738371566
# 15           0        1.54      RE  1738371568
# 31           0        5.34      AU  1738371586
# 76           0        7.20      AU  1738371641

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_cities_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""
# Display sample data
hotel_df.head()
# Out:
#               City Country      Lat       Lng  Humidity Hotel Name
# 7      east london      ZA -33.0153   27.9116        68
# 13  sarandi del yi      UY -33.3500  -55.6333        57
# 15     les avirons      RE -21.2418   55.3394        69
# 31         mildura      AU -34.2000  142.1500        40
# 76   alice springs      AU -23.7000  133.8833         8

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 100000
params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key, 
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
   

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = response.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# east london - nearest hotel: No hotel found
# sarandi del yi - nearest hotel: No hotel found
# les avirons - nearest hotel: Floralys
# mildura - nearest hotel: Chaffey Motor Inn
# alice springs - nearest hotel: Aurora Alice Springs
# saint-pierre - nearest hotel: Tropic Hotel
# salta - nearest hotel: Ayres de Salta Hotel
# ghanzi - nearest hotel: Ghanzi farmhouse
# bubaque - nearest hotel: Chez Julio
# san jose de jachal - nearest hotel: San Martin
# uturoa - nearest hotel: Hawaiki Nui hotel
# margaret river - nearest hotel: Margaret River Hotel
# mejit - nearest hotel: No hotel found
# mount isa - nearest hotel: Ibis Styles
# cabo san lucas - nearest hotel: Comfort Rooms
# iguala de la independencia - nearest hotel: Hotel Señorial
# salalah - nearest hotel: Muscat International Hotel
# chicoana - nearest hotel: Hostal Los Faroles
# alindao - nearest hotel: No hotel found
# frontera - nearest hotel: Quirino
# brisas de zicatela - nearest hotel: Casa de Olas
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# kolondieba - nearest hotel: No hotel found
# nova sintra - nearest hotel: Residência Ka Dencho
# manay - nearest hotel: RGD Inn
# santo antonio - nearest hotel: Pousada Onça Puma
# ciudad lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# codrington - nearest hotel: 54 on Bank
# geraldton - nearest hotel: Ocean Centre Hotel
# djenne - nearest hotel: Hotel Chez Baba
# sinnar - nearest hotel: No hotel found
# kinablangan - nearest hotel: RGD Inn
# champerico - nearest hotel: Hotel y Restaurante El Submarino
# tionk essil - nearest hotel: Campement Edonia
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# mukalla - nearest hotel: فندق الجابري
# itamaraca - nearest hotel: No hotel found
# san juan - nearest hotel: Hotel San Francisco
# port augusta - nearest hotel: Hotel Commonwealth
# collie - nearest hotel: Federal Hotel
# karratha - nearest hotel: Karratha International Hotel
# la'ie - nearest hotel: No hotel found
# carnarvon - nearest hotel: No hotel found
# broken hill - nearest hotel: Ibis Styles
# naracoorte - nearest hotel: Kincraig Hotel /Smith & Jones Cafe
# massawa - nearest hotel: Seghen International Hotel فندق دولي سيغن
#                            City Country      Lat       Lng  Humidity  \
# 7                   east london      ZA -33.0153   27.9116        68
# 13               sarandi del yi      UY -33.3500  -55.6333        57
# 15                  les avirons      RE -21.2418   55.3394        69
# 31                      mildura      AU -34.2000  142.1500        40
# 76                alice springs      AU -23.7000  133.8833         8
# 86                 saint-pierre      RE -21.3393   55.4781        69
# 110                       salta      AR -24.7859  -65.4117        74
# 125                      ghanzi      BW -21.5667   21.7833        36
# 131                     bubaque      GW  11.2833  -15.8333        64
# 132          san jose de jachal      AR -30.2406  -68.7469        29
# 158                      uturoa      PF -16.7333 -151.4333        73
# 167              margaret river      AU -33.9500  115.0667        58
# 188                       mejit      MH  10.2753  170.8646        70
# 192                   mount isa      AU -20.7333  139.5000        31
# 204              cabo san lucas      MX  22.8909 -109.9124        53
# 238  iguala de la independencia      MX  18.3500  -99.5333        29
# 243                     salalah      OM  17.0151   54.0924        23
# 263                    chicoana      AR -25.1009  -65.5331        64
# 311                     alindao      CF   5.0267   21.2088        28
# 313                    frontera      MX  26.9333 -101.4500        17
# 316          brisas de zicatela      MX  15.8369  -97.0419        74
# 318               mount gambier      AU -37.8333  140.7667        25
# 320                  kolondieba      ML  11.0882   -6.8926        16
# 321                 nova sintra      CV  14.8667  -24.7167        71
# 323                       manay      PH   7.2150  126.5397        68
# 327               santo antonio      BR  -6.3106  -35.4789        65
# 340      ciudad lazaro cardenas      MX  17.9583 -102.2000        70
# 344                  codrington      AU -38.2667  141.9667        37
# 364                   geraldton      AU -28.7667  114.6000        65
# 400                      djenne      ML  13.9061   -4.5533        15
# 401                      sinnar      SD  13.5691   33.5672        22
# 428                 kinablangan      PH   7.6947  126.5503        73
# 436                  champerico      GT  14.3000  -91.9167        71
# 449                 tionk essil      SN  12.7856  -16.5217        14
# 455             lazaro cardenas      MX  17.9583 -102.2000        70
# 460                     mukalla      YE  14.5425   49.1242        54
# 487                   itamaraca      BR  -7.7478  -34.8256        73
# 488                    san juan      AR -31.5375  -68.5364        26
# 501                port augusta      AU -32.5000  137.7667        13
# 508                      collie      AU -33.3667  116.1500        45
# 517                    karratha      AU -20.7377  116.8463        58
# 528                       la'ie      US  21.6477 -157.9253        70
# 531                   carnarvon      AU -24.8667  113.6333        54
# 537                 broken hill      AU -31.9500  141.4333        26
# 544                  naracoorte      AU -36.9579  140.7383        20
# 549                     massawa      ER  15.6097   39.4500        67
#
#                                     Hotel Name
# 7                               No hotel found
# 13                              No hotel found
# 15                                    Floralys
# 31                           Chaffey Motor Inn
# 76                        Aurora Alice Springs
# 86                                Tropic Hotel
# 110                       Ayres de Salta Hotel
# 125                           Ghanzi farmhouse
# 131                                 Chez Julio
# 132                                 San Martin
# 158                          Hawaiki Nui hotel
# 167                       Margaret River Hotel
# 188                             No hotel found
# 192                                Ibis Styles
# 204                              Comfort Rooms
# 238                             Hotel Señorial
# 243                 Muscat International Hotel
# 263                         Hostal Los Faroles
# 311                             No hotel found
# 313                                    Quirino
# 316                               Casa de Olas
# 318                 The Old Mount Gambier Gaol
# 320                             No hotel found
# 321                       Residência Ka Dencho
# 323                                    RGD Inn
# 327                          Pousada Onça Puma
# 340                     Hotel Sol del Pacífico
# 344                                 54 on Bank
# 364                         Ocean Centre Hotel
# 400                            Hotel Chez Baba
# 401                             No hotel found
# 428                                    RGD Inn
# 436           Hotel y Restaurante El Submarino
# 449                           Campement Edonia
# 455                     Hotel Sol del Pacífico
# 460                               فندق الجابري
# 487                             No hotel found
# 488                        Hotel San Francisco
# 501                         Hotel Commonwealth
# 508                              Federal Hotel
# 517               Karratha International Hotel
# 528                             No hotel found
# 531                             No hotel found
# 537                                Ibis Styles
# 544         Kincraig Hotel /Smith & Jones Cafe
# 549  Seghen International Hotel فندق دولي سيغن

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display
map_plot = None

# Configure the map plot
map_plot = hotel_df.hvplot.points(
    'Lng', 'Lat', 
    geo=True,
    color='City', 
    alpha=0.6, 
    tiles='OSM', 
    frame_width=800, 
    frame_height=600, 
    hover_cols=['City', 'Country', 'Hotel Name',]
)


# Display the map
map_plot.opts(opts.Points(tools=['hover'], colorbar=True, size=10))
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Country,Hotel Name)
